# %% [markdown]
# starting 14:30

# %%
# %load_ext autoreload
# %autoreload 2
# %cd /home/hess/projects/cmip-gan

# %%
from src.fractals import Fractals

# %%
frac = Fractals()
frac.compute_dimension()

# %%
fname = f'/p/tmp/hess/scratch/cmip-gan/results/figures/fractal_dim_global.pdf' 
frac.plot(fname)
# Out:
# /p/tmp/hess/scratch/cmip-gan/results/figures/fractal_dim_global.pdf
